# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %% [markdown]
# # Importing the data

# %%
file = 'FB_Data.xlsx'
data = pd.ExcelFile(file)
ardiinnam = data.parse('Ardiin_nam_reaction')
ardchilsannam = data.parse('ardchilsan_nam_reaction')
zuwhunnam = data.parse('zuw_hun_reaction')

# %% [markdown]
# # Cleaning Data

# %%
message_ardiinnam = ardiinnam.loc[:308,'message']
message_ardchilsannam = ardchilsannam['message']
message_zuvhun = zuwhunnam['message']

# %%
message_ardiinnam.head()
message_ardchilsannam.head()
message_zuvhun.head()
# Out:
# 0                                                  NaN
# 1    Т.Доржханд: ХҮН намын ард талд маш олон мэргэж...
# 2    Т.Доржханд: Сонгуулийн систем болохгүй байна г...
# 3    Б.Найдалаа: Орон нутгийн сонгуульд ХҮН нам бүх...
# 4    "ЗӨВ ХҮН ЭЛЕКТОРАТ"  эвслээс  УИХ-ын сонгуулий...
# Name: message, dtype: object

# %%
text_ardiinnam =' '.join(message_ardiinnam.astype(str))
text_ardchilsannam = ' '.join(message_ardchilsannam.astype(str))
text_zuvhun = ' '.join(message_zuvhun.astype(str))

# %% [markdown]
# # Creating a wordcloud

# %%
my_cloud = WordCloud(stopwords=['нэр','https'], background_color='White').generate(text_ardiinnam)
plt.imshow(my_cloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
my_cloud = WordCloud(stopwords=['нэр','https'], background_color='White').generate(text_ardchilsannam)
plt.imshow(my_cloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
my_cloud = WordCloud(stopwords=['нэр','https'], background_color='White').generate(text_zuvhun)
plt.imshow(my_cloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# # Creating word dictionary

# %%
def word_dic(text):
    word_count={}
    for word in text : 
        if word in word_count.keys():
            word_count[word]+=1
        else:
            word_count[word]=1
    return (word_count)

# break the string into list of words 
str_list_1 = text_ardiinnam.split() 
str_list_2 = text_ardchilsannam.split()
print(type(str_list_2))
str_list_3 = text_zuvhun.split()

a = word_dic(str_list_1)
sorted_dic_1 = sorted(a.items(), key=lambda x: x[1], reverse=True)
print(sorted_dic_1)
# Out:
# <class 'list'>
# [('✅', 275), ('🇲🇳🇲🇳🇲🇳', 176), ('ХҮЧЭЭ', 151), ('Монгол', 118), ('НЭГТГЭЕ!', 113), ('Ардын', 85), ('ТӨЛӨӨ', 79), ('сонгуулийн', 79), ('нэр', 76), ('УИХ-ын', 75), ('МЭДЭЭ', 61), ('дэвшигч', 61), ('тойрог,', 58), ('2020-2024', 57), ('Намаас', 55), ('орон', 51), ('ХӨГЖЛИЙН', 49), ('МОНГОЛ', 45), ('Хөгжлийн', 43), ('гэрээ', 42), ('бий', 40), ('аймагт', 38), ('дүүрэгт', 36), ('нь', 32), ('хөтөлбөр', 31), ('болгоно', 28), ('байна', 27), ('АРДЫН', 25), ('байгуулна', 25), ('хэрэгжүүлнэ', 24), ('мөрийн', 23), ('нэгдсэн', 22), ('🇲🇳', 22), ('ашиглалтад', 21), ('төв', 21), ('байна.', 20), ('болон', 20), ('байр', 20), ('болно', 20), ('НАМЫН', 19), ('улс', 19), ('сууцны', 19), ('МӨРИЙН', 19), ('газрын', 18), ('дахин', 18), ('гэр', 18), ('удаа', 17), ('хөтөлбөрийг', 17), ('#ХӨГЖЛИЙН_ГЭРЭЭ', 17), ('онд', 16), ('нэмэгдүүлнэ', 16), ('эрүүл', 16), ('ХӨТӨЛБӨР', 16), ('орчин', 16), ('намын', 16), ('хэрэгжүүлнэ.', 16), ('ажлын', 15), ('тогтолцоог', 15), ('2016-2020', 15), ('УЛСЫН', 14), ('НЭГТГЭХ', 14), ('уурхайн', 14), ('бүрэн', 14), ('нэг', 14), ('үйлдвэрийн', 14), ('улсын', 14), ('Намын', 14), ('их', 13), ('иргэн', 13), ('эрх', 13), ('барьж', 13), ('ипотекийн', 13), ('үндэсний', 13), ('болгож,', 13), ('хүүхдийн', 13), ('нийгмийн', 13), ('🇲🇳🇲🇳', 13), ('тойрог', 13), ('төрийн', 12), ('хувь', 12), ('төлөө', 12), ('аж', 12), ('үйлдвэр', 12), ('уул', 12), ('МАН-ын', 12), ('хүчээ', 12), ('бүр', 12), ('байгаа', 12), ('Баянзүрх', 12), ('Ерөнхий', 12), ('бүрдүүлнэ', 12), ('жил', 12), ('зам', 12), ('болгоно.', 12), ('#ХҮЧЭЭ_НЭГТГЭЕ!🇲🇳', 12), ('2020', 11), ('дарга', 11), ('оруулна', 11), ('төмөр', 11), ('эдийн', 11), ('үр', 11), ('зээл', 11), ('#МАН-аас', 11), ('засгийн', 11), ('санхүүгийн', 11), ('мэндийн', 11), ('төлдөг', 11), ('худалдан', 11), ('дэмжлэг', 11), ('бүрдүүлнэ.', 11), ('штабаас..', 11), ('байдлыг', 10), ('НЭГТГЭЕ!🇲🇳🇲🇳🇲🇳', 10), ('хөгжүүлнэ', 10), ('бохирдлыг', 10), ('тэтгэврийн', 10), ('баялгийн', 10), ('ажил', 10), ('дунд', 10), ('САНАЛАА', 10), ('хүнд', 10), ('Чингэлтэй', 10), ('хэмжээг', 10), ('чиглэлийн', 10), ('багаар', 9), ('#МАН-ын', 9), ('шударга', 9), ('зээлийн', 9), ('✅Уул', 9), ('анх', 9), ('боловсруулах', 9), ('шинэ', 9), ('хангана', 9), ('хот', 9), ('дэмжиж', 9), ('Уул', 9), ('иргэдэд', 9), ('хувийн', 9), ('насны', 9), ('хамгаалах', 9), ('чиглэлээр', 9), ('зүйн', 9), ('2', 9), ('жилд', 9), ('нэмэгдүүлж,', 9), ('даатгал', 9), ('урьдчилгаа', 9), ('хүртээмжийг', 9), ('үйлчилгээг', 9), ('олон', 9), ('даатгалын', 9), ('сууцтай', 9), ('үе', 9), ('ажиллаж', 9), ('#МОНГОЛ', 8), ('албан', 8), ('бууруулна', 8), ('авто', 8), ('буй', 8), ('эх', 8), ('хүн', 8), ('хуулийн', 8), ('жилийн', 8), ('хувиар', 8), ('орлоготой', 8), ('хүүтэй', 8), ('ИРЭЭДҮЙН', 8), ('бага', 8), ('иргэдийн', 8), ('сая', 8), ('150', 8), ('мянган', 8), ('сууц', 8), ('хүртэлх', 8), ('25-р', 8), ('барина', 8), ('Нийгмийн', 8), ('хөгжлийн', 8), ('боломжийг', 8), ('хүүхдэд', 8), ('Хөвсгөл', 8), ('·', 8), ('#3', 8), ('дэвшигчид', 8), ('тойрогтоо', 8), ('Монголын', 7), ('НЬ', 7), ('оны', 7), ('10', 7), ('-', 7), ('ажлыг', 7), ('төлбөргүй', 7), ('Хүүхдийн', 7), ('Үндэсний', 7), ('олгоно', 7), ('нийт', 7), ('үйл', 7), ('ажиллах', 7), ('зардлыг', 7), ('зээлд', 7), ('олгох', 7), ('1', 7), ('түүхий', 7), ('ЭРҮҮЛ', 7), ('үйлчилгээний', 7), ('шинээр', 7), ('МАН', 7), ('4', 7), ('Биелэлт', 7), ('хөдөлмөр', 7), ('сургууль,', 7), ('замыг', 7), ('хэрэгцээ', 7), ('(хөгжлийн', 7), ('иргэд,', 7), ('олгоно.', 7), ('nan', 6), ('дахь', 6), ('болох', 6), ('ард', 6), ('Улсын', 6), ('байх', 6), ('дэмжсэн', 6), ('мөнгөний', 6), ('бус', 6), ('хүүг', 6), ('4-6', 6), ('У.Хүрэлсүх', 6), ('сан', 6), ('гэж', 6), ('уу?', 6), ('аймгийн', 6), ('хотын', 6), ('50', 6), ('төслийг', 6), ('хөрөнгө', 6), ('хууль', 6), ('#ЗАЛУУСАА', 6), ('хүүхэд', 6), ('дүүргийн', 6), ('хүчний', 6), ('3', 6), ('бизнес', 6), ('зориулсан', 6), ('бүсийн', 6), ('ОРОН', 6), ('авахдаа', 6), ('хамрагддаг', 6), ('боломж', 6), ('чанар,', 6), ('төгрөгийн', 6), ('өрхийг', 6), ('барилгын', 6), ('бүхий', 6), ('төрөөс', 6), ('км', 6), ('ӨГЧ', 6) ...

# %%
b = word_dic(str_list_2)
sorted_dic_2 = sorted(b.items(), key=lambda x: x[1], reverse=True)
print(sorted_dic_2)
# Out:
# [('✅', 137), ('АРДЧИЛСАН', 75), ('Ардчилсан', 72), ('СОНГУУЛИЙН', 65), ('НАМЫН', 63), ('цаг', 63), ('та', 63), ('авч', 59), ('ТӨВ', 58), ('БҮРД', 57), ('ШТАБААС', 57), ('БЭЛТГЭЖ', 57), ('БАЙГАА', 57), ('МЭДЭЭ”', 57), ('сонгогч', 55), ('хүлээн', 55), ('бүрийн', 54), ('12:06', 54), ('минут', 54), ('15:00', 54), ('19:00', 54), ('үзээрэй', 54), ('цагаас', 53), ('УИХ-ын', 52), ('нэр', 52), ('ӨРХ', 48), ('сонгуулийн', 43), ('намаас', 41), ('“ЭРХ', 39), ('ЧӨЛӨӨНИЙ', 39), ('өдөр', 39), ('тойрог', 38), ('нь', 34), ('дэвшигч', 31), ('🇲🇳🇲🇳🇲🇳', 29), ('бүрд', 29), ('#Өсөлтийг_өрх_бүрд🇲🇳🇲🇳🇲🇳', 29), ('nan', 27), ('ОРЛОГО', 27), ('ХӨГЖЛИЙН', 26), ('ӨСӨЛТИЙГ', 26), ('байна.', 26), ('МОНГОЛ', 24), ('аймагт', 24), ('ХҮН', 22), ('Монгол', 21), ('орон', 20), ('"ӨСӨЛТИЙН', 19), ('ТУХАЙ', 19), ('-', 18), ('БОДЛОГО', 18), ('🇲🇳', 18), ('“ЯЛАЛТЫН', 18), ('БАГ', 18), ('ЯРЪЯ"', 18), ('ПОДКАСТ:', 18), ('2020', 17), ('ӨСӨЛТ', 17), ('хэрэгжүүлнэ.', 17), ('👏👏👏', 17), ('нам', 17), ('бүхий', 16), ('НЭР', 16), ('Өдөр', 16), ('ӨСӨЛТ✅', 15), ('УИХ-ЫН', 15), ('эдийн', 15), ('эрх', 14), ('дүүрэгт', 14), ('улс', 13), ('АН-ын', 13), ('бодлого', 13), ('Өрх', 13), ('албан', 12), ('болон', 12), ('хөгжлийн', 12), ('төрийн', 12), ('Хүн', 12), ('ДЭВШИГЧ', 12), ('аж', 11), ('ч', 11), ('ТОЙРОГТ', 11), ('хүн', 10), ('байгаа', 10), ('тусгай', 10), ('үзэл', 10), ('ДЭМЖСЭН_ХӨГЖЛИЙН', 10), ('✅✅✅', 10), ('байна', 9), ('Улсын', 9), ('ДЭМЖСЭН', 9), ('эрүүл', 9), ('ЭРХТЭЙ', 9), ('үеийн', 9), ('ТӨРӨӨ', 9), ('ЗАСЪЯ...', 9), ('ХҮРГЭНЭ', 9), ('шинэ', 9), ('иргэдэд', 9), ('итгэж', 9), ('оны', 8), ('дахин', 8), ('бий', 8), ('ЭРХ', 8), ('тогтвортой', 8), ('байх', 8), ('болгох', 8), ('бүхэнд', 8), ('зориулсан', 8), ('АН', 8), ('улсын', 8), ('•', 8), ('мөрийн', 8), ('#Өсөлтийг_өрх_бүрд', 8), ('намын', 7), ('НАМ', 7), ('2020🇲🇳', 7), ('ахуйн', 7), ('АРДЧИЛЛАА', 7), ('ЭДИЙН', 7), ('хөтөлбөрийг', 7), ('МОНГОЛ🇲🇳', 7), ('засгийн', 7), ('орлого', 7), ('ЭЗЭН', 7), ('иргэдийн', 7), ('бол', 7), ('төлөө', 7), ('өрх', 7), ('#Монгол_өрх_хөгжлийн_бодлого_мөрийн_хөтөлбөрөөс🇲🇳🇲🇳🇲🇳', 7), ('ажлын', 6), ('байдал,', 6), ('хорооллын', 6), ('ипотекийн', 6), ('ДЭМЖИНЭ', 6), ('тухай', 6), ('хүний', 6), ('бүр', 6), ('гэдэгт', 6), ('ахуй', 6), ('үр', 6), ('замаар', 6), ('гэр', 6), ('Барилга', 6), ('хэрэгцээт', 6), ('зам,', 6), ('шат', 6), ('хэрэгсэл', 6), ('Олон', 6), ('иргэн,', 6), ('БАЯНГОЛ', 6), ('дэвшигчиддээ', 6), ('ялалт,', 6), ('амжилтыг', 6), ('хүсье', 6), ('хуулийн', 6), ('хийж', 5), ('сонгуулийн', 5), ('иргэд,', 5), ('сонгуульд', 5), ('онд', 5), ('хувь', 5), ('хэмжээг', 5), ('өмнө', 5), ('хэмжээнд', 5), ('зардлыг', 5), ('татварын', 5), ('зүйн', 5), ('зээлийг', 5), ('Гэр', 5), ('НЬ', 5), ('ДҮҮРГИЙН', 5), ('МӨРИЙН', 5), ('ТАНД', 5), ('асуудлаар', 5), ('мэдээлэл', 5), ('эх', 5), ('тэгш', 5), ('амьдрах', 5), ('бодлогыг', 5), ('нийтийн', 5), ('100', 5), ('иргэн', 5), ('бэрхшээлтэй', 5), ('10', 5), ('орны', 5), ('энэ', 5), ('мянган', 5), ('хүүхдийн', 5), ('байгууламж', 5), ('санхүүгийн', 5), ('зэрэг', 5), ('дүүргийн', 5), ('засаг', 5), ('нутгийн', 5), ('ХҮРТЭЭМЖТЭЙ', 5), ('хөрөнгө', 5), ('нэг', 5), ('хүргэх', 5), ('С.Эрдэнэ', 5), ('чөлөөт', 5), ('жил', 5), ('ИРГЭД_СОНГОГЧДЫН', 5), ('УУЛЗАЛТ', 5), ('чадна', 5), ('иргэд', 5), ('#Монгол_өрх_хөгжлийн_бодлого_2020✅✅✅', 5), ('байгууллага,', 5), ('байдлын', 4), ('АРДЧИЛАЛ', 4), ('БАЙНА', 4), ('ГЭР', 4), ('шинээр', 4), ('байсан', 4), ('хүртэл', 4), ('орчинд', 4), ('боломж', 4), ('аюулгүй', 4), ('уялдуулна.', 4), ('төлөвлөлтийг', 4), ('СОНГОНО', 4), ('БАГААР', 4), ('дэд', 4), ('дарга', 4), ('АНХ', 4), ('УДАА', 4), ('ТУСГАЙ', 4), ('ХЭРЭГЦЭЭТ', 4), ('ХӨТӨЛБӨРӨӨ', 4), ('МЯНГАН', 4), ('НИЙГМИЙГ', 4), ('БИЙ', 4), ('БАС', 4), ('ХАМААТАЙ', 4), ('ба', 4), ('шийдэл', 4), ('зорилтот', 4), ('ажиллах', 4), ('цогц', 4), ('малчин', 4), ('дэмжинэ.', 4), ('Эрх', 4), ('тэргүүлэх', 4), ('зорилгоор', 4), ('орлогыг', 4), ('олон', 4), ('болгон', 4), ('хөтөлбөр', 4), ('ажлыг', 4), ('спорт', 4), ('барилга', 4), ('нэгдсэн', 4), ('шинэчлэн', 4), ('оролцоотой', 4), ('хэрэгжүүлж,', 4), ('хуулийг' ...

# %%
c=word_dic(str_list_3)
sorted_dic_3 = sorted(c.items(), key=lambda x: x[1], reverse=True)
print(sorted_dic_3)
# Out:
# [('нэр', 92), ('Зөв', 82), ('Электорат', 79), ('байна.', 78), ('Хүн', 67), ('нь', 65), ('#Сонгууль2020', 60), ('✅', 56), ('Монгол', 52), ('сонгуулийн', 45), ('#ЗөвХүн', 42), ('улс', 39), ('#Зөвхүн', 39), ('дэвшигч', 39), ('эвслийн', 36), ('Радио', 36), ('хүн', 33), ('төрийн', 32), ('эвслээс', 32), ('ХҮН', 30), ('ЗӨВ', 29), ('тойрогт', 28), ('оны', 27), ('сонгуульд', 26), ('хүлээн', 26), ('мөрийн', 26), ('гэж', 25), ('бид', 24), ('УИХ-ын', 24), ('2020', 24), ('зөв', 23), ('та', 22), ('байгаа', 22), ('бүхэн', 21), ('буюу', 21), ('#Зөвхандлага', 20), ('эрх', 20), ('хөтөлбөрийг', 20), ('шинэ', 19), ('буй', 19), ('Энэ', 18), ('болон', 18), ('Та', 18), ('вэ?', 18), ('өнөөдөр', 18), ('Их', 17), ('#Зөвбодлого', 17), ('#ЗөвБодлого', 17), ('Улс', 17), ('уу.', 17), ('ч', 16), ('АЙЖ', 16), ('БАЙНА...', 16), ('авна', 16), ('төр', 16), ('хөгжлийн', 16), ('бодлого', 16), ('Улсын', 16), ('#ЗөвхүнЭлекторат', 16), ('nan', 15), ('ард', 15), ('л', 15), ('юм.', 15), ('УИХ-н', 15), ('доорх', 15), ('үр', 14), ('Монголын', 14), ('ТА', 14), ('таны', 14), ('их', 13), ('сонголт', 13), ('энэ', 13), ('өдөр', 13), ('Иргэн', 13), ('дагуу', 13), ('Эвслээс', 13), ('#зөвхүн', 13), ('#зөвхүнЭлекторат', 13), ('эдийн', 12), ('30', 12), ('дүүрэгт', 12), ('цагийн', 12), ('эх', 12), ('БИД', 12), ('Бид', 12), ('#ЗөвХүнЭлекторатЭвсэл', 12), ('дэвшиж', 12), ('Мөрийн', 12), ('монгол', 12), ('орон', 12), ('хөрөнгө', 12), ('Хурлын', 12), ('хуваарийн', 12), ('олон', 11), ('хэн', 11), ('боломж', 11), ('#ХуучнааХалъя', 11), ('авч', 11), ('НАРААС', 11), ('шууд', 11), ('мэт', 11), ('бэлтгэсэн', 11), ('-', 11), ('хөтөлбөрийн', 11), ('бодлогын', 11), ('нам', 10), ('дэвшигчид', 10), ('орноо', 10), ('хууль', 10), ('хийж', 10), ('бол', 10), ('гурван', 10), ('Нэр', 10), ('засгийн', 10), ('тухай', 9), ('гэсэн', 9), ('#ЗөвХандлага', 9), ('албан', 9), ('бидэнд', 9), ('эвсэл', 9), ('улсын', 9), ('ажил', 9), ('Эх', 9), ('бүр', 9), ('хөгжлийг', 9), ('нэг', 9), ('төлөө', 9), ('нар', 9), ('огт', 9), ('дэвшигчдийн', 9), ('бүрэн', 9), ('#сонгууль2020', 9), ('цагаас', 9), ('байг.', 9), ('мэргэжлийн', 8), ('тогтолцоог', 8), ('хамгийн', 8), ('юу', 8), ('мэдээлэл', 8), ('сурталчилгааны', 8), ('жил', 8), ('өөрчлөх', 8), ('"Зөв', 8), ('ёс', 8), ('оролцож', 8), ('ЧИНЬ', 8), ('цагт', 8), ('гэх', 8), ('бидний', 8), ('арга', 8), ('эхээр', 8), ('сая', 8), ('http://www.zuvhunelectorat.mn/program', 8), ('88.8:', 8), ('ИХ', 8), ('ФМ', 8), ('Инээмсэглэл', 8), ('99.3:', 8), ('98.9:', 8), ('байна.', 8), ('намын', 7), ('маш', 7), ('Сонгуулийн', 7), ('байна', 7), ('бүх', 7), ('болох', 7), ('хийх', 7), ('төрийг', 7), ('хуудас', 7), ('хүч,', 7), ('4', 7), ('Баянзүрх', 7), ('Өнөөдөр', 7), ('Баянгол', 7), ('иргэд,', 7), ('дэмжигч', 7), ('“Зөв', 7), ('дарга', 7), ('дараах', 7), ('бус', 7), ('тулд', 7), ('орны', 7), ('тойрог', 7), ('тэд', 7), ('дахин', 7), ('тул', 7), ('5', 7), ('бүхий', 7), ('хэрэгжүүлэх', 7), ('технологийг', 7), ('хүний', 7), ('байдлыг', 7), ('яагаад', 7), ('маань', 7), ('аж', 7), ('хөтөлбөр', 7), ('Бизнес', 7), ('99.7:', 7), ('цагаа', 7), ('6-р', 7), ('бий.', 6), ('онд', 6), ('итгэл', 6), ('аянаа', 6), ('Сонгогч', 6), ('#ЗөвХөгжье', 6), ('жилд', 6), ('болсон', 6), ('дараа', 6), ('тэргүүнд', 6), ('хүмүүс', 6), ('МОНГОЛ', 6), ('сонгогч', 6), ('тойрог,', 6), ('хүсэл', 6), ('инженер', 6), ('хэрхэн', 6), ('хөтөлбөр,', 6), ('болж', 6), ('мэдээллийг', 6), ('Ийм', 6), ('замаар', 6), ('ухааны', 6), ('доктор', 6), ('бодит', 6), ('дугаар', 6), ('эрчим', 6), ('2016', 6), ('өнгөрсөн', 6), ('амлалт', 6), ('эрхээ', 6), ('минь', 6), ('би', 6), ('дэд', 6), ('унших', 6), ('технологийн', 6), ('үеийн', 6), ('мэдээллийн', 6), ('тус', 6), ('#ЗӨВХүн', 6), ('MNB', 6), ('сарын', 6), ('эвсэл-с', 6), ('удаа', 5), ('байр', 5), ('гэдгийг', 5), ('ашиглаж', 5), ('дээрх', 5), ('боломжийг', 5), ('хандив', 5), ('илэрхийлж', 5), ('ирээдүйг', 5), ('#Зөв', 5), ('гаж', 5), ('ирээдүйгээ', 5), ('#Зөвхөн', 5), ('Электорат"', 5), ('сайхан', 5), ('бэ?', 5), ('22-р', 5), ('Шинэ', 5), ('авсан', 5), ('дүүргийн', 5), ('Яг', 5), ('болно', 5),  ...

# %% [markdown]
# # Cleaning the data

# %%
bad_words = ['✅','🇲🇳🇲🇳🇲🇳','сонгуулийн','нэр','УИХ-ын','МЭДЭЭ','дэвшигч','Намаас','УИХ','Монгол']

# %%
from wordcloud import WordCloud, STOPWORDS
stopwords= set(STOPWORDS)
stopwords.update(bad_words)

# %%
# my_cloud = WordCloud(stopwords=stopwords, background_color='White').generate(text)
# plt.imshow(my_cloud, interpolation='bilinear')
# plt.axis('off')
# plt.show()

# %%
ardiin_reaction = ardiinnam.iloc[309:,10:]
ardchilsan_reaction = ardchilsannam.iloc[1:,9:]
zuwhun_reaction = zuwhunnam.iloc[1:,10:]

# %% [markdown]
# # Which type is most common

# %%
ardiin_reaction['type'].value_counts()
# Out:
# video    224
# link      59
# photo     20
# Name: type, dtype: int64

# %%
ardchilsan_reaction['type'].value_counts()
# Out:
# video    216
# photo     90
# link      27
# Name: type, dtype: int64

# %%
zuwhun_reaction['type'].value_counts()
# Out:
# photo     74
# link      50
# video     48
# status    25
# Name: type, dtype: int64

# %% [markdown]
# # Shares summary statistics

# %%
table_a = pd.pivot_table(ardiin_reaction,values = ['shares.count','comments.summary.total_count','reactions.summary.total_count','like.summary.total_count','love.summary.total_count','haha.summary.total_count','wow.summary.total_count','sad.summary.total_count','angry.summary.total_count'],index='type')

# %%
table_b = pd.pivot_table(ardchilsan_reaction,values = ['shares.count','comments.summary.total_count','reactions.summary.total_count','like.summary.total_count','love.summary.total_count','haha.summary.total_count','wow.summary.total_count','sad.summary.total_count','angry.summary.total_count'],index='type')

# %%
table_c = pd.pivot_table(zuwhun_reaction,values = ['shares.count','comments.summary.total_count','reactions.summary.total_count','like.summary.total_count','love.summary.total_count','haha.summary.total_count','wow.summary.total_count','sad.summary.total_count','angry.summary.total_count'],index='type')
